# %% [markdown]
# # Simone - AI Music Server (Lyria RealTime)
#
# **无需 GPU！** 使用 Google Lyria RealTime API，只需要 Gemini API Key。
#
# **使用方法：**
# 1. 在 Cell 2 填入你的 `GEMINI_API_KEY`
# 2. 运行 Cell 2 → Cell 3
# 3. Cell 3 会输出 `wss://xxx.trycloudflare.com` 地址
# 4. 在 Simone 页面点 ⚙️ 齿轮粘贴地址，回车
#
# **重启服务（换 URL）：** 只需重跑 Cell 3

# %%
# ====== Cell 2: 安装依赖 + 设置 API Key ======
# !pip install -q google-genai websockets nest_asyncio

import os
os.environ['GEMINI_API_KEY'] = ''  # ← 填入你的 Gemini API Key

print('\n✅ 就绪！运行 Cell 3 启动服务器。')

# %%
# ====== Cell 3: 从 GitHub 拉取最新 server 代码并启动 ======
import urllib.request
server_url = 'https://raw.githubusercontent.com/Oldfishermannn/DJ-LaoYu/main/colab_server.py'
print('Fetching colab_server.py from GitHub...')
resp = urllib.request.urlopen(server_url)
server_code = resp.read().decode('utf-8')
print(f'Got {len(server_code)} bytes, starting server...\n')
compiled = compile(server_code, 'colab_server.py', 'exec')
run_globals = dict(globals())
run_globals['GEMINI_API_KEY'] = os.environ.get('GEMINI_API_KEY', '')
run_globals['__name__'] = '__main__'
exec(compiled, run_globals)  # noqa: S102 - trusted code from our own repo
